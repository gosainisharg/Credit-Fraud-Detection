# %% [markdown]
# #CREDIT FRAUD DETECTION USING MACHINE LEARNING
#
# Workflow:
# Gather Data -> Preprocess Data -> Data Analysis -> Split Data -> Logistic Regression(Machine Learning) -> Evaluation/Conclusion
#
# Goal: To predict a transaction is legitimate/fraud.

# %% [markdown]
# # Importing Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split #splits data into training & testing
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Loading csv data from kaggle stored in google drive

# %%
# loading dataset to pandas DataFrame
crd_data = pd.read_csv('/content/drive/MyDrive/Datasets/creditcard.csv')

# %% [markdown]
# # Displaying the data and EDA

# %%
crd_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#features are in numerical values since card data is sensitive information, this is done through principal component analysis
# we have time, features, amount, class as our columns
# label 0 in class column represents legit transaction and label 1 represents fraudulent transaction

crd_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
#dataset info
crd_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
#no missing values but we can check for missing values in each column
crd_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#distribution of legit transaction and fraud transaction
crd_data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
# 492 fraud transactions only, unbalanced dataset

# %%
#separating data for analysis based on legit and fraud transac
legit_tr = crd_data[crd_data.Class == 0]
fraud_tr = crd_data[crd_data.Class == 1]

# %%
print(legit_tr.shape)
print(fraud_tr.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
#Statistical Measures of the data
legit_tr.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud_tr.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
#mean transac is more for fraud transactions

# %%
#compare the values for both transactions
crd_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
#the ML will use this difference to predict

# %% [markdown]
# # Dealing with Unbalanced Data
# ## We will use undersampling
# Build a sample dataset from original dataset having similar distribution of legit and fraudulent transactions
# Randomly pick 492 legit transaction and all 492 fraud transactions

# %%
#pick 492 legit transactions using random sampling
legit_sample = legit_tr.sample(n=492)

# %%
#concat legit sample and fraud transac
new_crd_data = pd.concat([legit_sample,fraud_tr], axis = 0) #we need to mention axis = 0 this will add row wise, we dont want column wise

# %%
new_crd_data.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 143263   85230.0  1.183333  1.033242 -1.776886  1.426153  1.042692 -0.901881
# 10505    17250.0 -1.837346  1.385192  1.785974  1.251958 -1.180291  0.686071
# 15160    26513.0 -0.782705  0.797540  1.193985 -1.510033  0.030690 -0.128575
# 189240  128317.0  1.908646 -2.039701 -0.779283 -1.280538 -1.842519 -0.869347
# 122043   76414.0  1.532573 -1.156719  0.496650 -1.626292 -1.426948 -0.031299
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 143263  0.437823  0.046127 -0.351405  ... -0.178274 -0.520595 -0.205113
# 10505  -0.745951  1.245750  0.700188  ...  0.096292  0.390893 -0.110541
# 15160   0.312831  0.254076  0.177237  ... -0.067280 -0.146617 -0.032484
# 189240 -1.016587 -0.247525 -0.988750  ... -0.032801 -0.012054  0.098705
# 122043 -1.424811  0.092698 -1.711011  ... -0.075720  0.160416 -0.099767
#
# ...

# %%
new_crd_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_crd_data.describe()
# Out:
#                 Time          V1          V2          V3          V4  \
# count     984.000000  984.000000  984.000000  984.000000  984.000000
# mean    87512.159553   -2.402541    1.777759   -3.547876    2.277400
# std     48754.722455    5.531572    3.755798    6.191349    3.208182
# min        49.000000  -30.552380  -15.170680  -31.103685   -4.837170
# 25%     44526.000000   -2.939486   -0.162643   -5.074851   -0.036997
# 50%     79701.500000   -0.905227    0.977849   -1.407127    1.334262
# 75%    135360.250000    1.084863    2.845852    0.269031    4.235631
# max    172543.000000    2.375383   22.057729    3.467385   12.114672
#
#                V5          V6          V7          V8          V9  ...  \
# count  984.000000  984.000000  984.000000  984.000000  984.000000  ...
# mean    -1.537933   -0.682622   -2.826212    0.252953   -1.280944  ...
# std      4.225882    1.780418    5.828104    4.897315    2.340743  ...
# ...

# %%
new_crd_data['Class'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 984 entries, 143263 to 281674
# Series name: Class
# Non-Null Count  Dtype
# --------------  -----
# 984 non-null    int64
# dtypes: int64(1)
# memory usage: 15.4 KB

# %%
new_crd_data['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
new_crd_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94277.512195 -0.033134 -0.068260 -0.062470  0.012770  0.075358
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.032492 -0.083693 -0.064731  0.019235  ...  0.010790  0.007376
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.033134 -0.028551  0.027562  0.039376 -0.007977  0.000423  0.016959
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       93.297033
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
#nature of the dataset has not changed
#this means we got a good sample, if the means were changed drastically it would mean a bad sample

# %% [markdown]
# # Splitting dataset into features and targets
# X -> Features
# Y -> Targets

# %%
X = new_crd_data.drop(columns = 'Class',axis = 1) #drop Class column
Y = new_crd_data['Class']

# %%
print(X)
print(Y)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 143263   85230.0  1.183333  1.033242 -1.776886  1.426153  1.042692 -0.901881
# 10505    17250.0 -1.837346  1.385192  1.785974  1.251958 -1.180291  0.686071
# 15160    26513.0 -0.782705  0.797540  1.193985 -1.510033  0.030690 -0.128575
# 189240  128317.0  1.908646 -2.039701 -0.779283 -1.280538 -1.842519 -0.869347
# 122043   76414.0  1.532573 -1.156719  0.496650 -1.626292 -1.426948 -0.031299
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %% [markdown]
# # Splitting data into training and testing data
# ##We will use train_test_split(),
# ##20% of data will be testing data
# ###stratify insures even distribution of 0 and 1 in test and train data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %% [markdown]
# # Model Training
# ## Logistic Regression

# %%
model = LogisticRegression()

# %%
#training model using training data
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
#very less data points, training can take long time if more data points

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
#accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction,Y_train)

# %%
print('Accuracy on training data:',training_data_accuracy)
# Out:
# Accuracy on training data: 0.9174078780177891

# %%
#good accuracy score on training data
#but need to check on test data

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction,Y_test)

# %%
print('Accuracy on testing data:',test_data_accuracy)
# Out:
# Accuracy on testing data: 0.8984771573604061

# %% [markdown]
# If accuracy scores are different for training and test data then we need to check for overfitting or underfitting, but we are fine in this case.
